# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Book1.csv")
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club join year  \
# 0           70           76.0           68.0               99            2022
# 1           65           65.0           69.0               85            2023
# 2           68           82.0           65.0               99            2018
# 3           90           76.0           68.0               82            2019
# 4           76            NaN           89.0               91            2019
# 5           61           83.0           70.0               90            2019
# 6           76            NaN            NaN               78            2022
# 7           74           84.0           69.0               98            2018
# 8           86           88.0           79.0               75            2019
# 9           90           77.0            NaN               99            2022
# 10          66           69.0           77.0               85            2023
# ...

# %%
df.isnull().sum()
# Out:
# Math Score               0
# Reading Score            2
# Writing Score            2
# Placement Score          0
# Club join year           0
# Placement offer count    0
# dtype: int64

# %%
df['Writing Score'].dropna()
# Out:
# 0     68.0
# 1     69.0
# 2     65.0
# 3     68.0
# 4     89.0
# 5     70.0
# 7     69.0
# 8     79.0
# 10    77.0
# 11    78.0
# 12    77.0
# 13    82.0
# 14    80.0
# 15    74.0
# 16    60.0
# 17    72.0
# 18    78.0
# 19    89.0
# 20    63.0
# 21    62.0
# 22    78.0
# 23    65.0
# 24    60.0
# 25    86.0
# 26    60.0
# 27    70.0
# 28    76.0
# 29    86.0
# 30    69.0
# 31    81.0
# 32    62.0
# 33    64.0
# 34    69.0
# 35    77.0
# 36    82.0
# 37    76.0
# 38    70.0
# 39    88.0
# 40    87.0
# 41    80.0
# 42    79.0
# 43    71.0
# 44    84.0
# 45    79.0
# 46    87.0
# 47    86.0
# 48    89.0
# Name: Writing Score, dtype: float64

# %%
df['Reading Score'].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Math Score               0
# Reading Score            2
# Writing Score            2
# Placement Score          0
# Club join year           0
# Placement offer count    0
# dtype: int64

# %%
m1=df['Reading Score'].mean()
m1
# Out:
# 76.04255319148936

# %%
m1=df['Reading Score'].mean()
df2=df['Reading Score'].fillna(m1,inplace=True)
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club join year  \
# 0     1.457480      76.000000           68.0               99            2022
# 1     1.444712      65.000000           69.0               85            2023
# 2     1.452499      82.000000           65.0               99            2018
# 3     1.499968      76.000000           68.0               82            2019
# 4     1.471518      76.042553           89.0               91            2019
# 5     1.433680      83.000000           70.0               90            2019
# 6     1.471518      76.042553            NaN               78            2022
# 7     1.466981      84.000000           69.0               98            2018
# 8     1.492372      88.000000           79.0               75            2019
# 9     1.499968      77.000000            NaN               99            2022
# 10    1.447352      69.000000           77.0               85            2023
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club join year  \
# 0           70      76.000000           68.0               99            2022
# 1           65      65.000000           69.0               85            2023
# 2           68      82.000000           65.0               99            2018
# 3           90      76.000000           68.0               82            2019
# 4           76      76.042553           89.0               91            2019
# 5           61      83.000000           70.0               90            2019
# 7           74      84.000000           69.0               98            2018
# 8           86      88.000000           79.0               75            2019
# 10          66      69.000000           77.0               85            2023
# 11          76      87.000000           78.0               83            2023
# 12          78      84.000000           77.0               90            2021
# ...

# %%
df.isnull().sum()
# Out:
# Math Score               0
# Reading Score            0
# Writing Score            0
# Placement Score          0
# Club join year           0
# Placement offer count    0
# dtype: int64

# %%
import numpy as np
m2=df['Math Score'].mean()
df['Math Score']=np.where((df['Math Score']<60) | (df['Math Score']>90),m2,df['Math Score'])
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club join year  \
# 0    70.000000      76.000000           68.0               99            2022
# 1    65.000000      65.000000           69.0               85            2023
# 2    68.000000      82.000000           65.0               99            2018
# 3    90.000000      76.000000           68.0               82            2019
# 4    76.000000      76.042553           89.0               91            2019
# 5    61.000000      83.000000           70.0               90            2019
# 7    74.000000      84.000000           69.0               98            2018
# 8    86.000000      88.000000           79.0               75            2019
# 10   66.000000      69.000000           77.0               85            2023
# 11   76.000000      87.000000           78.0               83            2023
# 12   78.000000      84.000000           77.0               90            2021
# ...

# %%
df.sum()
# Out:
# Math Score                3424.340426
# Reading Score             3573.042553
# Writing Score             3530.000000
# Placement Score           4160.000000
# Club join year           94944.000000
# Placement offer count      111.000000
# dtype: float64

# %%
df.count()
# Out:
# Math Score               47
# Reading Score            47
# Writing Score            47
# Placement Score          47
# Club join year           47
# Placement offer count    47
# dtype: int64

# %%
plt.figure(figsize =(10, 7))
plt.boxplot(df['Math Score'])
plt.show()

# %%
from scipy.stats import skew
import seaborn as sns
for col in df:
    print(col)
    print(skew(df[col]))
    # plt.figure()
    # sns.distplot(df[col])
    # plt.show()
# Out:
# Math Score
# 0.25810537579528003
# Reading Score
# -0.30038633049364255
# Writing Score
# nan
# Placement Score
# -0.0727034222170501
# Club join year
# 0.25810537579528003
# Placement offer count
# -0.6218680623897693
# Placement Scorer
# 0.02740156992096087

# %%
plt.figure()
sns.distplot(df["Placement offer count"])
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Temp\ipykernel_11056\2189122855.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Placement offer count"])

# %%
df["Placement offer count"]=df['Placement offer count']**2
skew(df["Placement offer count"])
# Out:
# -0.2806110198833401

# %%
df["Placement offer count"]=df['Placement offer count']**2
skew(df["Placement offer count"])
plt.figure()
sns.distplot(df["Placement offer count"])
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Temp\ipykernel_11056\1051447204.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Placement offer count"])
