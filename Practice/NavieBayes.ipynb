# %%
import pandas as pd

df = pd.read_csv('IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(8)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa

# %%
unique_species = df['species'].unique()

# Print the unique species names
print(unique_species)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X=df.iloc[:,:4]
y=df['species']

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=2)
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 70            5.9          3.2           4.8          1.8
# 46            5.1          3.8           1.6          0.2
# 68            6.2          2.2           4.5          1.5
# 88            5.6          3.0           4.1          1.3
# 69            5.6          2.5           3.9          1.1
# 67            5.8          2.7           4.1          1.0
# 137           6.4          3.1           5.5          1.8
# 58            6.6          2.9           4.6          1.3
# 33            5.5          4.2           1.4          0.2
# 38            4.4          3.0           1.3          0.2
# 103           6.3          2.9           5.6          1.8
# 51            6.4          3.2           4.5          1.5
# 107           7.3          2.9           6.3          1.8
# 4             5.0          3.6           1.4          0.2
# 102           7.1          3.0           5.9          2.1
# ...

# %%
gnb = GaussianNB()

gnb.fit(X_train,y_train)
y_pred = gnb.predict([[6.5,3.0,5.8,2.2]])
y_pred
# Out:
# D:\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype='<U15')

# %%
df.iloc[104]
# Out:
# sepal_length               6.5
# sepal_width                3.0
# petal_length               5.8
# petal_width                2.2
# species         Iris-virginica
# Name: 104, dtype: object

# %%
setosa = df[df['species'] == 'Iris-setosa']
versicolor = df[df['species'] == 'Iris-versicolor']
virginica = df[df['species'] == 'Iris-virginica']

test_sample = [6.5,3.0,5.8,2.2]

# Calculate mean and standard deviation for each feature grouped by species
setosa_mean = setosa.iloc[:,:4].mean()
setosa_std = setosa.iloc[:,:4].std()

versicolor_mean = versicolor.iloc[:,:4].mean()
versicolor_std = versicolor.iloc[:,:4].std()

virginica_mean = virginica.iloc[:,:4].mean()
virginica_std = virginica.iloc[:,:4].std()

from scipy.stats import norm

# Probability densities for test sample in 'Iris-setosa'
probabilities_setosa = [
    norm.pdf(test_sample[i], setosa_mean[i], setosa_std[i]) for i in range(4)
]

probabilities_versicolor = [
    norm.pdf(test_sample[i], versicolor_mean[i], versicolor_std[i]) for i in range(4)
]

# Probability densities for test sample in 'not Iris-setosa'
probabilities_virginica = [
    norm.pdf(test_sample[i], virginica_mean[i], virginica_std[i]) for i in range(4)
]

prob_setosa = np.prod(probabilities_setosa)
prob_versicolor = np.prod(probabilities_versicolor)
prob_virginica = np.prod(probabilities_virginica)

total_prob = prob_setosa + prob_versicolor + prob_virginica

normalized_prob_setosa = prob_setosa / total_prob
normalized_prob_versicolor = prob_versicolor / total_prob
normalized_prob_virginica = prob_virginica / total_prob

if( (normalized_prob_setosa > normalized_prob_versicolor) & (normalized_prob_setosa > normalized_prob_virginica)):
    print("Iris-setosa")
elif((normalized_prob_versicolor > normalized_prob_setosa) & (normalized_prob_versicolor > normalized_prob_virginica)):
    print("Iris-versicolor")
else:
    print("Iris-virginica")
# Out:
# Iris-virginica
# C:\Users\sneha\AppData\Local\Temp\ipykernel_20444\3679544489.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   norm.pdf(test_sample[i], setosa_mean[i], setosa_std[i]) for i in range(4)
# C:\Users\sneha\AppData\Local\Temp\ipykernel_20444\3679544489.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   norm.pdf(test_sample[i], versicolor_mean[i], versicolor_std[i]) for i in range(4)
# ...
